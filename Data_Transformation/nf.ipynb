# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

""" CARGA DE DATOS """
df = pd.read_excel('./../netflix_titles.xlsx')

# %%
""" EXPLORACION DE DATOS """
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6406 entries, 0 to 6405
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6406 non-null   int64
#  1   type          6406 non-null   object
#  2   title         6406 non-null   object
#  3   director      4273 non-null   object
#  4   cast          5820 non-null   object
#  5   country       5919 non-null   object
#  6   date_added    6384 non-null   object
#  7   release_year  6406 non-null   int64
#  8   rating        6395 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 600.7+ KB

# %%
df.isna().any()
# Out:
# show_id         False
# type            False
# title           False
# director        False
# cast            False
# country         False
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# description     False
# dtype: bool

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.isna().sum().plot(kind='hist')
plt.show()

# %%
df.sample(2)
# Out:
#        show_id   type                      title     director  \
# 5392  70045274  Movie              Evan Almighty  Tom Shadyac
# 731   70280748  Movie  Russell Peters: Notorious   Dave Higby
#
#                                                    cast        country  \
# 5392  Steve Carell, John Goodman, Molly Shannon, Lau...  United States
# 731                                      Russell Peters  United States
#
#             date_added  release_year rating duration  \
# 5392    April 16, 2019          2007     PG   96 min
# 731   October 14, 2013          2013     NR   72 min
#
#                                               listed_in  \
# 5392  Children & Family Movies, Comedies, Faith & Sp...
# 731                                     Stand-Up Comedy
#
#                                             description
# 5392  God summons narcissistic Evan to build an ark ...
# 731   Global comedy star Russell Peters leaves no et...

# %%
""" Limpieza """
df.fillna(0)

df.head(
    
)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1               No definido
# 2               No definido
# 3               No definido
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
df.fillna(0, inplace=True)

# %%
df['director'].replace({0:'No definido'}, inplace =True)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1               No definido
# 2               No definido
# 3               No definido
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
df[df['country']=='Other']

df['country'].value_counts()
# Out:
# United States                                    2102
# India                                             777
# United Kingdom                                    374
# Japan                                             188
# Canada                                            154
#                                                  ...
# India, Japan                                        1
# Norway, Germany, Sweden                             1
# United Kingdom, Canada, France, United States       1
# United Arab Emirates, Jordan                        1
# Paraguay, Argentina                                 1
# Name: country, Length: 554, dtype: int64

# %%
df.head()
# Out:
#              type                                    title  \
# show_id
# 81145628    Movie  Norm of the North: King Sized Adventure
# 80117401    Movie               Jandino: Whatever it Takes
# 70234439  TV Show                       Transformers Prime
# 80058654  TV Show         Transformers: Robots in Disguise
# 80125979    Movie                             #realityhigh
#
#                           director  \
# show_id
# 81145628  Richard Finn, Tim Maltby
# 80117401                       NaN
# 70234439                       NaN
# 80058654                       NaN
# 80125979          Fernando Lebrija
#
#                                                        cast  \
# show_id
# 81145628  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 80117401                                   Jandino Asporaat
# 70234439  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 80058654  Will Friedle, Darren Criss, Constance Zimmer, ...
# ...

# %%
df.drop('description', axis= 1, inplace=True)
df.head()

# %%
""" ANALISIS """
print(df['type'].value_counts().sum())
# Out:
# 6406

# %%
df['type'].value_counts()
# Out:
# Movie      4266
# TV Show    2140
# Name: type, dtype: int64

# %%
df.groupby('type')['country'].value_counts()
# Out:
# type     country
# Movie    United States                               1482
#          India                                        724
#          United Kingdom                               170
#          Canada                                        88
#          Spain                                         80
#                                                      ...
# TV Show  United States, Russia                          1
#          United States, Spain, Colombia, Mexico         1
#          United States, Sweden                          1
#          United States, United Kingdom, Australia       1
#          United States, United Kingdom, Canada          1
# Name: country, Length: 636, dtype: int64

# %%
print(df['rating'].value_counts())
# Out:
# TV-MA       2081
# TV-14       1750
# TV-PG        721
# R            508
# PG-13        286
# NR           221
# PG           185
# TV-Y7        182
# TV-Y         157
# TV-G         156
# TV-Y7-FV     102
# G             37
# UR             7
# NC-17          2
# Name: rating, dtype: int64

# %%
df['rating'].value_counts(normalize =True)
# Out:
# TV-MA       0.325410
# TV-14       0.273651
# TV-PG       0.112744
# R           0.079437
# PG-13       0.044722
# NR          0.034558
# PG          0.028929
# TV-Y7       0.028460
# TV-Y        0.024550
# TV-G        0.024394
# TV-Y7-FV    0.015950
# G           0.005786
# UR          0.001095
# NC-17       0.000313
# Name: rating, dtype: float64

# %%
df.to_excel('C:/Users/Jordin/Desktop/DATACAMP/netflix_titles_cambios.xlsx')
